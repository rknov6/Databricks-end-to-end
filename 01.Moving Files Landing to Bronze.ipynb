# %%
from pyspark.sql.types import StructType,StructField,IntegerType,StringType,TimestampType,DateType,DecimalType

# %%
df_customer = spark.read.option("header","true").csv("/Volumes/restaurant/landing/operational/customers.csv")
df_customer.writeTo("restaurant.bronze.customers").createOrReplace()

# %%
df_customer_reviews = spark.read.option("header","true").csv("/Volumes/restaurant/landing/operational/customer_reviews.csv")
df_customer_reviews.writeTo("restaurant.bronze.customer_reviews").createOrReplace()

# %%
# %sql
select * from read_files("/Volumes/restaurant/landing/operational/historical_orders.csv",format => "csv",header => "true",escape => '"')

# %%
df_historical_orders = spark.read.option("header","true").option("inferSchema", "true").option("escape",'"').csv("/Volumes/restaurant/landing/operational/historical_orders.csv")
df_historical_orders.writeTo("restaurant.bronze.historical_orders").createOrReplace()

# %%
df_menu_items = spark.read.option("header","true").csv("/Volumes/restaurant/landing/operational/menu_items.csv")
df_menu_items.writeTo("restaurant.bronze.menu_items").createOrReplace()

# %%
df_restaurants = spark.read.option("header","true").csv("/Volumes/restaurant/landing/operational/restaurants.csv")
df_restaurants.writeTo("restaurant.bronze.restaurants").createOrReplace()

# %%
spark.sql("""
          select * from restaurant.bronze.restaurants
          """).display()
